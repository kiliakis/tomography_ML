# %%
import pickle as pk
import pandas as pd
import os
import glob

# %%
hparam_trials_list = [
    './hparam_trials/2023_03_28*',
    './hparam_trials/2023_04_19*',
    './hparam_trials/2023_04_20*',
    './hparam_trials/2023_04_25*',
    ]

# %%
# expand regexps in list
temp_list = []
for trial in hparam_trials_list:
    temp_list += glob.glob(trial)
hparam_trials_list = temp_list

for trial in hparam_trials_list:
    print(trial)
# Out:
# ./hparam_trials/2023_03_28_16-48-42
# ./hparam_trials/2023_03_28_09-02-27
# ./hparam_trials/2023_03_28_09-02-30
# ./hparam_trials/2023_03_28_09-43-35
# ./hparam_trials/2023_03_28_10-01-37
# ./hparam_trials/2023_03_28_13-41-08
# ./hparam_trials/2023_03_28_13-45-22
# ./hparam_trials/2023_03_28_16-02-43
# ./hparam_trials/2023_04_19_14-00-08
# ./hparam_trials/2023_04_19_14-00-12
# ./hparam_trials/2023_04_19_18-49-13
# ./hparam_trials/2023_04_19_18-49-15
# ./hparam_trials/2023_04_20_09-43-15
# ./hparam_trials/2023_04_20_09-43-17
# ./hparam_trials/2023_04_25_17-07-31
# ./hparam_trials/2023_04_25_17-07-34
# ./hparam_trials/2023_04_25_16-21-09
# ./hparam_trials/2023_04_25_16-21-13

# %%
all_temp_data = []
for triali, trial in enumerate(hparam_trials_list):
    dir = os.path.join(trial, 'hparams')

    for file in os.listdir(dir):
        variable = file.split('_')[0]
        path = os.path.join(dir, file)
        data = pk.load(open(path, 'rb'))
        all_data_d = {}
        for k, v in data.items():
            unique_key = f'{variable}-{triali}-{k}'
            if 'run' not in all_data_d:
                all_data_d['run'] = []
            all_data_d['run'].append(k.split('-')[1])
            # if 'run' not in all_data_d:
            #     all_data_d['run'] = []
            # all_data_d['run'].append(k.split('-')[1])
            if 'var' not in all_data_d:
                all_data_d['var'] = []
            all_data_d['var'].append(variable)
            for cat, value in v.items():
                if cat == 'history':
                    epochs = len(v['history']['loss'])
                    if 'epochs' not in all_data_d:
                        all_data_d['epochs'] = []
                    all_data_d['epochs'].append(epochs)
                else:
                    if isinstance(value, list):
                        value = '-'.join(str(e) for e in value)
                    if cat not in all_data_d:
                        all_data_d[cat] = []
                    all_data_d[cat].append(value)
        temp_data = pd.DataFrame(all_data_d)
        all_temp_data.append(temp_data)
data = pd.concat(all_temp_data)
data.head()
data = data.sort_values(by=['var', 'valid'])

# %%
data[data['var']=='mu'].head(20)

# %%
data[data['var']=='VrfSPS'].head(20)
# Out:
#    run     var        time     train     valid  epochs cropping  filters  \
# 16  16  VrfSPS  101.997655  0.000115  0.000134      50    14-14     8-32
# 3    3  VrfSPS  144.701893  0.000189  0.000148      50    14-14     8-16
# 20  20  VrfSPS   96.264102  0.000184  0.000150      50    14-14  8-16-32
# 11  11  VrfSPS  106.978998  0.000187  0.000154      50    14-14  4-16-64
# 4    4  VrfSPS  139.399100  0.000194  0.000154      50    14-14     8-16
# 28  28  VrfSPS   92.133987  0.000200  0.000158      50    14-14  4-16-64
# 6    6  VrfSPS  101.971128  0.000180  0.000159      50    14-14  8-16-32
# 9    9  VrfSPS  104.020391  0.000168  0.000159      50    14-14  8-16-32
# 10  10  VrfSPS  105.960660  0.000179  0.000160      50    14-14  4-16-64
# 8    8  VrfSPS  152.017369  0.000172  0.000164      50    14-14  4-16-64
# 10  10  VrfSPS  157.327345  0.000191  0.000166      50    14-14     8-32
# 10  10  VrfSPS   95.053542  0.000156  0.000166      50    14-14     4-16
# 23  23  VrfSPS   93.192075  0.000183  0.000170      50    14-14  8-16-32
# 21  21  VrfSPS   97.644890  0.000162  0.000172      50    14-14      4-8
# 7    7  VrfSPS  158.839926  0.000203  0.000172      50    14-14  4-16-64
# 2    2  VrfSPS  149.979054  0.000181  0.000172      50    14-14   4-8-16
# 5    5  VrfSPS  158.488403  0.000184  0.000174      50    14-14  8-16-32
# 9    9  VrfSPS  160.394046  0.000153  0.000175      50    14-14     8-32
# 5    5  VrfSPS  139.665895  0.000212  0.000175      50    14-14     8-16
# 27  27  VrfSPS   95.515905  0.000216  0.000176      50    14-14  4-16-64
#
#    kernel_size  dense_layers strides pooling  data% batchnorm use_bias  \
# 16         9-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 3         13-9  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 20       7-7-7  1024-512-256     NaN     NaN    1.0       NaN      NaN
# 11       5-5-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 4          9-9  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 28      11-5-3  1024-512-256     NaN     NaN    1.0       NaN      NaN
# 6        5-5-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 9        9-7-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 10       7-7-7  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 8        7-5-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 10         9-9  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 10        11-7  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 23      11-5-3  1024-512-256     NaN     NaN    1.0       NaN      NaN
# 21         9-5  1024-512-256     NaN     NaN    1.0       NaN      NaN
# 7        9-9-9  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 2        7-5-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 5        7-5-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 9         13-9  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 5          7-5  1024-256-128     NaN     NaN    1.0       NaN      NaN
# 27       3-3-3  1024-512-256     NaN     NaN    1.0       NaN      NaN
#
#    conv_padding
# 16         same
# 3          same
# 20         same
# 11         same
# 4          same
# 28         same
# 6          same
# 9          same
# 10         same
# 8          same
# 10         same
# 10         same
# 23         same
# 21         same
# 7          same
# 2          same
# 5          same
# 9          same
# 5          same
# 27         same

# %%
data.strides.unique()
# Out:
# array([nan, '2-2', '3-3', '1-1'], dtype=object)
